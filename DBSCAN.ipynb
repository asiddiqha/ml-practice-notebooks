# %% [markdown]
# <a href="https://colab.research.google.com/github/asiddiqha/ai-workbench/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 2], hue=y)
plt.show()

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.8, min_samples=5)
dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.8)

# %%
labels = dbscan.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 2], hue=labels)
plt.show()

# %%
# Non Linear Data

from sklearn.datasets import make_moons
X, y = make_moons(n_samples=1000, noise=0.05, random_state=42)

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
plt.show()

# %%
X_scaled = scaler.fit_transform(X)
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=y)
plt.show()

# %%
# K-Means

from sklearn.cluster import KMeans
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
y_pred = kmeans.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=y_pred)
plt.show()

# %%
# DBSCAN

dbscan = DBSCAN(eps=0.2, min_samples=5)
y_pred = dbscan.fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:, 0], y=X_scaled[:, 1], hue=y_pred)
plt.show()
